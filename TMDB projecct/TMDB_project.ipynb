# %%
# key =  f8cbf468b77c8249cc7d767ea8a3798f  
# token = eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJmOGNiZjQ2OGI3N2M4MjQ5Y2M3ZDc2N2VhOGEzNzk4ZiIsInN1YiI6IjYzZWZhOGU0Y2RkYmJjMDA4YzIwZDViZiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.vvxMD8fmsj7DY2THYk6zR6OEhoIXc-thw-XHbEc2low

# %% [markdown]
# read the dosumnetation of TMDb API before start

# %% [markdown]
# **Problem : 1**
# Find the 'id' of the movie "Andhadhun" using TMDb API.

# %%
import requests

## both the way works 
header = {'Authorization': 'Bearer f8cbf468b77c8249cc7d767ea8a3798f','Content-Type': 'application/json;charset=utf-8'}
param = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f","query":"Andhadhun"}
# Search for the movie "Andhadhun"
# url = search/movie?api_key=f8cbf468b77c8249cc7d767ea8a3798f&query=Andhadhun"
url = "https://api.themoviedb.org/3/search/movie?"
response = requests.get(url,headers=header,params= param)
data = response.json()
# print(data)
print(data["results"][0]["id"])
# Out:
# 534780

# %% [markdown]
# **Problem : 2**
# Fetch the company id company 'Marvel Studios' using TMDb. Print the id.

# %%
import requests

## both the way works 
header = {'Authorization': 'Bearer f8cbf468b77c8249cc7d767ea8a3798f','Content-Type': 'application/json;charset=utf-8'}
param = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f","query":"Marvel Studios"}
# Search for the movie "Andhadhun"
# url = f"https://api.themoviedb.org/3/search/movie?api_key=f8cbf468b77c8249cc7d767ea8a3798f&query=Andhadhun"
url = "https://api.themoviedb.org/3/search/company"
response = requests.get(url,headers=header,params= param)
data = response.json()
# print(data)
print(data["results"][0]["id"])
# Out:
# 420

# %% [markdown]
# **Problem : 3**
# Find the vote count and vote average of the movie "3 Idiots" using the TMDb API

# %%
import requests

## both the way works 
header = {'Authorization': 'Bearer f8cbf468b77c8249cc7d767ea8a3798f','Content-Type': 'application/json;charset=utf-8'}
param = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f","query":"3 Idiots"}
# Search for the movie "Andhadhun"
# url = f"https://api.themoviedb.org/3/search/movie?api_key=f8cbf468b77c8249cc7d767ea8a3798f&query=Andhadhun"
url = "https://api.themoviedb.org/3/search/movie?"
response = requests.get(url,headers=header,params= param)
data = response.json()
# print(data)
print(data["results"][0]["vote_count"],data["results"][0]["vote_average"])
# Out:
# 2035 7.98

# %% [markdown]
# **Problem : 4**
# Fetch the names of top 5 similar movies to 'Inception' from the TMDb API.
# *Note :*
#
#     While fetching the movie id, use the "original_title" field not the "title". Because the "title" field may contain duplicate values.

# %% [markdown]
# question is wrong if we are getting origianl title it is showing error just get the title only

# %%
import requests

## both the way works 
header = {'Authorization': 'Bearer f8cbf468b77c8249cc7d767ea8a3798f','Content-Type': 'application/json;charset=utf-8'}
param = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f","query":"Inception"}
# url = f"https://api.themoviedb.org/3/search/movie?api_key=f8cbf468b77c8249cc7d767ea8a3798f&query=Andhadhun"
url = "https://api.themoviedb.org/3/search/movie?"
response = requests.get(url,headers=header,params= param)
data = response.json()
id = data["results"][0]["id"]
# print(id)
query = {"api_key"  : "f8cbf468b77c8249cc7d767ea8a3798f","language":"en-US"}
url = f"https://api.themoviedb.org/3/movie/{id}/similar?"
data = requests.get(url,params=query)
data = data.json()
similar = data["results"][:5]
title = [movie["title"] for movie in similar ]
for i in title :
    print(i)
# Out:
# Stone of Destiny
# Room of Death
# The Long Kiss Goodnight
# The Mission
# Dead Presidents

# %% [markdown]
# **Problem : 5**
# Fetch the top rated english movies in the US region using the TMDb API. From the result, print the first 10 movies which have original language as english. Also print their genres.
# Note: Do not use the search/movies API for finding genres.

# %%
import requests 

#### will fetch the top ratted movie first 
url = "https://api.themoviedb.org/3/movie/top_rated"
header = {'Authorization': 'Bearer f8cbf468b77c8249cc7d767ea8a3798f','Content-Type': 'application/json;charset=utf-8'}
qyery = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f","language" :"en-US","region":"US"}

response = requests.get(url,headers=header , params=qyery)
data = response.json()["results"]
# print(data)
counter = 1 
for i in data:
    if i['original_language'] == "en" and counter <11:
        movie_name = i["title"]
        genre_id = i["genre_ids"]
        counter+=1
        genre_url = "https://api.themoviedb.org/3/genre/movie/list"
        header_genre = {'Authorization': 'Bearer f8cbf468b77c8249cc7d767ea8a3798f','Content-Type': 'application/json;charset=utf-8'}
        query_genre = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f","language" :"en-US"}
        response_genre = requests.get(genre_url,headers = header_genre, params=query_genre)
        data_genre = response_genre.json()["genres"]
        genre_name = [ i["name"] for i in data_genre if i["id"] in genre_id]
        # print(movie_name,"-",", ".join(genre_name))
        print(movie_name,end = " - ")
        for i in genre_name :
            print(i,end = ', ')
        print()
    elif counter == 11:
        break
# Out:
# The Godfather - Crime, Drama,
# The Shawshank Redemption - Crime, Drama,
# The Boy, the Mole, the Fox and the Horse - Adventure, Animation, Family, Fantasy,
# The Godfather Part II - Crime, Drama,
# Schindler's List - Drama, History, War,
# 12 Angry Men - Drama,
# The Green Mile - Crime, Drama, Fantasy,
# The Dark Knight - Action, Crime, Drama, Thriller,
# Pulp Fiction - Crime, Thriller,
# Forrest Gump - Comedy, Drama, Romance,

# %% [markdown]
# **Problem : 6**
# Find the name and birthplace of the present most popular person according to TMDb API.

# %%
import requests 

url = "https://api.themoviedb.org/3/person/popular"
param = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f"}
response = requests.get(url,params= param)
data = response.json()["results"]
print(data[0]["id"])
# print(data)
print(data[0]["name"],end= "-")
# print(data[0]["origin_country"])
url = "https://api.themoviedb.org/3/person/75341"
data = requests.get(url,params=param)
data = data.json()
print(data["place_of_birth"])
# Out:
# 1253360
# Pedro Pascal-Zion, Illinois, USA

# %% [markdown]
# ### Problem : 7
#
#     Fetch the Instagram and Twitter handle of Indian Actress "Alia Bhatt" from the TMDb API.

# %%
import requests  
url = "https://api.themoviedb.org/3/search/person"
query = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f","query" : "Alia Bhatt"}
response = requests.get(url,params=query)
person_id = response.json()["results"][0]["id"]

url = f"https://api.themoviedb.org/3/person/{person_id}/external_ids"
response = requests.get(url,params={"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f"})
data = response.json()
print(data["instagram_id"],data["twitter_id"])
# Out:
# aliaabhatt Aliaa08

# %% [markdown]
# **Problem 8 : TMDb 2.3**
# Fetch the names of the character played by Tom Cruise in the movies:

# %% [markdown]
# step : 1 serch the movie and the id of the movie
# step : 2 check the movie section and the credit section in that you will be able to see the cast of the movie in the results

# %%
import requests 
l = ["Top Gun",'Mission: Impossible - Fallout','Minority Report','Edge of Tomorrow']

for movie in l :
    url = "https://api.themoviedb.org/3/search/movie"
    query = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f","query" : movie }
    response = requests.get(url,params=query)
    data = response.json()
    movie_id = data["results"][0]["id"]
    url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits"
    query2 = {"api_key" :"f8cbf468b77c8249cc7d767ea8a3798f"}
    response = requests.get(url,params=query2)
    # response = requests.get(url,params=query)
    data = response.json()
    print(data)
    print(data["cast"][0]["character"])
# Out:
# {'id': 744, 'cast': [{'adult': False, 'gender': 2, 'id': 500, 'known_for_department': 'Acting', 'name': 'Tom Cruise', 'original_name': 'Tom Cruise', 'popularity': 45.529, 'profile_path': '/8qBylBsQf4llkGrWR3qAsOtOU8O.jpg', 'cast_id': 13, 'character': "Lt. Pete 'Maverick' Mitchell", 'credit_id': '52fe426fc3a36847f801e6b9', 'order': 0}, {'adult': False, 'gender': 1, 'id': 11084, 'known_for_department': 'Acting', 'name': 'Kelly McGillis', 'original_name': 'Kelly McGillis', 'popularity': 19.974, 'profile_path': '/uaTBUCUpGYbc4nzO43PPIvmCREq.jpg', 'cast_id': 14, 'character': "Charlotte 'Charlie' Blackwood", 'credit_id': '52fe426fc3a36847f801e6bd', 'order': 1}, {'adult': False, 'gender': 2, 'id': 5576, 'known_for_department': 'Acting', 'name': 'Val Kilmer', 'original_name': 'Val Kilmer', 'popularity': 38.834, 'profile_path': '/asscfTVTglxMBEeJiDYxUXM4bm9.jpg', 'cast_id': 15, 'character': "Lt. Tom 'Iceman' Kazansky", 'credit_id': '52fe426fc3a36847f801e6c1', 'order': 2}, {'adult': False, 'ge
# ...

# %% [markdown]
# **Problem 9 : TMDb 2.4**
# Did James McAvoy play a role in the movie Deadpool 2. Print Yes or No.

# %%
import requests 

movie = "Deadpool 2"
url = "https://api.themoviedb.org/3/search/movie"
query = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f","query" : movie }

response = requests.get(url,params=query)
data = response.json()
movie_id = data["results"][0]["id"]
# print(movie_id)

url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits"
query2 = {"api_key" :"f8cbf468b77c8249cc7d767ea8a3798f"}
response = requests.get(url,params=query2)
data = response.json()
# print(data)
# James McAvoy
data = data["cast"]
for i in data :
    if i["name"] == "James McAvoy":
        print("Yes")
        break
else :
    print("No")
# Out:
# Yes

# %% [markdown]
# **Problem 10 : TMDb 2.5**
# Using the result obtained in previous question, find out if James McAvoy was credited for his role in movie Deadpool 2. Print Yes or No.

# %%
import requests 

movie = "Deadpool 2"
url = "https://api.themoviedb.org/3/search/movie"
query = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f","query" : movie }

response = requests.get(url,params=query)
data = response.json()
movie_id = data["results"][0]["id"]
# print(movie_id)

url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits"
query2 = {"api_key" :"f8cbf468b77c8249cc7d767ea8a3798f"}
response = requests.get(url,params=query2)
data = response.json()
# print(data)
# James McAvoy
data = data["cast"]
for i in data :
    if i["name"] == "James McAvoy":
        if "uncredited" in i["character"] :
            print("No")
            break
else :
    print("Yes") 
# if "uncredited" in info["character"]:
#     print("No")
# else :
#     print("Yes")
# Out:
# No

# %% [markdown]
# **Problem 11 : TMDb 3.1**
# Fetch the overview of the TV Show "FRIENDS" using TMDb API.

# %%
import requests 
query2 = {"api_key" :"f8cbf468b77c8249cc7d767ea8a3798f","query" : "FRIENDS"}
url = "https://api.themoviedb.org/3/search/tv"
response = requests.get(url,query2)
data = response.json()
### there are two overvies so we have to check all the values 
print(data["results"][0]["overview"])
print(data["results"][1]["overview"])
# Out:
# Six young people from New York City, on their own and struggling to survive in the real world, find the companionship, comfort and support they get from each other to be the perfect antidote to the pressures of life.
# Friends is a short-lived kids-oriented drama that aired in the spring of 1979. The series, which was produced by Aaron Spelling and aired on ABC, starred Charlie Aiken, Jill Whelan, and Jarrod Johnson as three Southern Californian 11-year-olds. Karen Morrow also appeared. Only five one-hour episodes were produced before the series was cancelled.

# %% [markdown]
# check the json file link there are two overview

# %%
import requests 
api_key = "e226f4a5f5bace766952aa0d17182959" 
api_link = "https://api.themoviedb.org/3" 
params = {'query':"Friends" , 'api_key':api_key} 
header = {'Accept': 'application/json'} 
response = requests.get(api_link + "/search/tv", headers = header, params = params) 
# data = response.json() 
print(response.url)
# results = data.get('results') 
# print(results)
# for result in results: 
#     if result.get('name') == 'Friends': 
#         print(result.get('overview'))
# Out:
# https://api.themoviedb.org/3/search/tv?query=Friends&api_key=e226f4a5f5bace766952aa0d17182959

# %% [markdown]
# **Problem 12: TMDb 3.1**
# Fetch the name and air date of S06E05 of the TV Show 'The Big Bang Theory' from TMDb API.

# %%
import requests 
query2 = {"api_key" :"f8cbf468b77c8249cc7d767ea8a3798f","query" : "The Big Bang Theory"}
url = "https://api.themoviedb.org/3/search/tv"
response = requests.get(url,query2)
data = response.json()
tv_id = data["results"][0]["id"]
season_number = 6
episode_number = 5
url = f"https://api.themoviedb.org/3/tv/{tv_id}/season/{season_number}/episode/{episode_number}"
query = {"api_key" :"f8cbf468b77c8249cc7d767ea8a3798f"}
response = requests.get(url,query)
### check the json file data by generating the url the name is present at the last of the data file "response.url"
data = response.json()
print(data["name"],"-",data["air_date"])
# Out:
# The Holographic Excitation - 2012-10-25

# %% [markdown]
# **Problem 13 :TMDb 3.3**
# Fetch the trending TV Shows for the week from the TMDb API and print the taglines of
# the top 5 shows. If there is no tagline, print 'Empty' instead

# %%
import requests

media_type = "tv"
time_window = "week"
url = f"https://api.themoviedb.org/3/trending/{media_type}/{time_window}"
query = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f"}

response = requests.get(url,params=query)
response.url
data = response.json()
data = data["results"][:5]
### store the ids of every tv show in the week becasue the is no tagline present in this URL 
ids = []
for show in data :
    ids.append(show["id"])

### now searcch the tagline by the id beccasue tagline is present in this url 
for tv_id in ids :
    url = f"https://api.themoviedb.org/3/tv/{tv_id}"
    response = requests.get(url,query)
    data = response.json()
    if data["tagline"] :
        print(data["tagline"])
    else:
        print("Empty")
# Out:
# When you're lost in the darkness, look for the light.
# Bounty hunting is a complicated profession.
# Empty
# We must all come together.
# Empty

# %% [markdown]
# **Problem 14 : TMDb 3.4**
#
# Print the names of all the TV shows to be aired today whose original language is english.

# %%
import requests 

url = "https://api.themoviedb.org/3/tv/airing_today"
query = {'api_key': 'f8cbf468b77c8249cc7d767ea8a3798f'}
response = requests.get(url,params=query)
# print(response.url)
data = response.json()
pages = data["total_pages"]

for i in range(1,pages+1):
    api_endpoint = "https://api.themoviedb.org/3/tv/airing_today"
    api_params = {'api_key': 'f8cbf468b77c8249cc7d767ea8a3798f',"page" : i,'language':'en'}
    response = requests.get(api_endpoint, params=api_params)
    # print(response.url)
    response_json = response.json()
    results = response_json["results"]
    for show in results:
        if show["original_language"] == "en":
            print(show["name"])
# Out:
# Love Island
# Naked News
# Saturday Night Live
# Ant & Dec's Saturday Night Takeaway
# Match of the Day
# RWBY
# Big City Greens
# Kids' Choice Awards
# Marvel's Moon Girl and Devil Dinosaur
# The Incredible Dr. Pol
# On Patrol: Live
# Michael McIntyre's The Wheel
# Pointless Celebrities
# On Patrol: First Shift
# The Try Guys
# Casualty
# Hamster & Gretel
# PBS News Weekend
# Work It Out Wombats!
# Love & Marriage: DC
# Masters of Illusion
# The Pit Stop
# NRL 2023
# Bettany Hughes' Treasures of the World
# WOW - Women of Wrestling
# WWE The SmackDown LowDown
# Starstruck
# Family Dinner
# Train Cruise
# Championship Wrestling from Memphis
# Ainsley's Fantastic Flavours
# Family Group
# Lonely Connections
# Frozen Planet II
# Click
# Ted's Notebook
# Celebrity Catchphrase
# Morning Joe: Weekend

# %% [markdown]
# **Problem 15 : TMDb 3.5**
# Count the number of males and females in the cast of "Money Heist" using the TMDb API.
#
# *NOTE :*
#
#      this is tv shwo not the move so search it in the tv shows

# %%
import requests

movie = "Money Heist"
url = "https://api.themoviedb.org/3/search/tv"
query = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f","query" : movie }
response = requests.get(url,query)
# response.url
data = response.json()
tv_id = data["results"][0]["id"]
# print(tv_id)

url = f"https://api.themoviedb.org/3/tv/{tv_id}/credits"
query2 = {"api_key" : "f8cbf468b77c8249cc7d767ea8a3798f"}
response = requests.get(url,params=query2)
# response.url
data = response.json()
results = data["cast"]
females,males = 0,0
for val in results :
    if val["gender"] == 1 :
        females+=1
    else :
        males+=1
print(males,females)
# Out:
# 10 5
