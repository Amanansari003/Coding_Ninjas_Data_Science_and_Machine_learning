# %% [markdown]
# **IMPORTANT NOTE THE TOKEN CAN EXPIRE IF YOU ARE USING THIS CODE ,MAKE SURE YOU ARE USING YOUR UPDATED TOKEN**

# %% [markdown]
# **Problem 1 : github organisation repo**
#
# Fetch the all repositories(except Forked repository) of organisation ‘CodingNinjasCodes’ from Github API using OAuth(access token)
# Print the name of repository with its watch count and fork count.

# %%
import requests

### this is url we can get from the guithub documentation into the left side scroll down and look for reposetory section 
url = "https://api.github.com/orgs/CodingNinjasCodes/repos"

## both the header are correct first one is old but second one is new method mention in GITHUB API documentation 
# headers = {"Authorization": "Bearer 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"}
headers = {"Accept": "application/vnd.github+json"}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    repos = response.json()
    # print(repos)
    for i in repos :
        if (i['fork']== False):
            print(i['name'],i['watchers_count'],i['forks_count'])
else:
    print("Error: ", response.status_code)

# %% [markdown]
# **Problem 2 : github organisation member**
#
# Fetch all the members of the organisation 'CodingNinjasCodes' from Github API using OAuth(access token).
# Print the username of members present in organisation.
# Please refer this file for new changes in github: Document

# %% [markdown]
# method and link will be avilable into the oragization section than into the member section

# %%
import requests 

header = {"Accept": "application/vnd.github+json","Authorization": "Bearer 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"}
url = "https://api.github.com/orgs/CodingNinjasCodes/members"
data = requests.get(url,headers=headers)
# print(data.status_code)
python_data = data.json()
for i in python_data:
    print(i["login"])

# %% [markdown]
# **Problem 3 : github repo contributors**
# Fetch the list of contributors in the repository 'CodingNinjasCodes/JSNotes' in Github from Github API using OAuth(access token).
# Print the username of contributors and its number of commit done.

# %% [markdown]
# method is present inoto the reposetory section  check out the guithub API documentation

# %%
import requests 

url = "https://api.github.com/repos/CodingNinjasCodes/JSNotes/contributors"
header = {"Accept" : "application/vnd.github+json",
        "Authorization": "Bearer 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",
        "X-GitHub-Api-Version": "2022-11-28"
}

data = requests.get(url,headers=header)
# print(data.status_code)
if data.status_code == 200:
    python_data = data.json()
    # print(python_data)
    for i in python_data:
        print(i["login"],i["contributions"])

else :
    print("Error:", data.status_code)

# %% [markdown]
# **Problem 4 : Github repo health**
# Fetch the health percentage of repository 'CodingNinjasCodes/SmoothScrollJs' in Github from Github API using OAuth(access token).
# Print the health percentage of Repository as Integer Value.
# Please refer this file for new changes in github: Document
# *Note:*
#
#      Check the Github API documentation of Community Profile

# %% [markdown]
# method and link will be avilable into the metrics section than the community section in GUIT hub api documentation

# %%
import requests 

url = "https://api.github.com/repos/CodingNinjasCodes/SmoothScrollJs/community/profile"
header = {"Accept" : "application/vnd.github+json",
        "Authorization": "Bearer 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",
        "X-GitHub-Api-Version": "2022-11-28"
}

data = requests.get(url,headers=header)
# print(data.status_code)
if data.status_code == 200:
    python_data = data.json()
    print(python_data["health_percentage"])
    # for i in python_data:
    #     print(i["login"],i["contributions"])

else :
    print("Error:", data.status_code)
# Out:
# 25

# %% [markdown]
# **Problem 4 : github all repo**
# Fetch the all repositories of organisation ‘fossasia’ from Github API using OAuth(access token)
# Print the name of repository.

# %%
import requests

### this is url we can get from the guithub documentation into the left side scroll down and look for reposetory section 
url = "https://api.github.com/orgs/fossasia/repos"

## both the header are correct first one is old but second one is new method mention in GITHUB API documentation 
headers = {"Authorization": "Bearer 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"}
# headers = {"Accept": "application/vnd.github+json"}

i=1
res = 100
data = []

### per_page is used becasue by default it will give use the only 30 reposetory and max limit it 100 so we set the 100 and page is basically per page 
while res == 100 :
    response = requests.get(url, headers=headers, params= {"per_page":100, "page":i})
    response = response.json()
    res = len(response)
    # print(res)
    data.extend(response)
    i+=1

for repo in data :
    print(repo["name"])
# Out:
# 100
# 100
# 42
# publiccode.asia
# labyrinth
# Flask_Simple_Form
# Ember_Simple_Calculator
# 2019.fossasia.org
# Connect-Me
# dmca
# meilix.org
# flask-rest-jsonapi
# susi_twitchbot
# susi_zulipbot
# snowboy
# gci18.fossasia.org
# pi-gen
# jp.pslab.io
# in.pslab.io
# fossasia-jekyll-theme
# fossasia.sg
# eventyay-artwork
# summit.fossasia.org
# photos.fossasia.org
# susi_installer
# susi_python
# susi_speech_server
# FOSSASIA-Office
# 2019.codeheat.org
# fossasia-presentations
# orgmanager
# hyderabad.jugaadfest.com
# delhi.jugaadfest.com
# speech_recognition
# led-name-badge-ls32
# Event-Safety-Measures
# libsigrokdecode
# libsigrok
# eventyay.de
# code.fossasia.org
# ember-l10n
# 2020.codeheat.org
# 2022.fossasia.org
# chatmosphere-app
# cmake-microchip
# x-mario
# phimpme-android
# phimpme-drupal
# xmario_buildscript
# pslab-case
# meilix-systemlock
# fossasia10-drupal
# fossasia11-drupal
# blog.fossasia.org
# 2010.fossasia.org
# 2014.fossasia.org
# meilix
# phimpme-wordpress
# ...
